# %%
import matplotlib.pyplot as plt
import pandas as pd

axs = plt.gca()

df = pd.read_json('res.txt')
df['time'] = df.index
df['vol'] = df['volume']/1000000
df.plot(kind='line', x='time', y='open', ax=axs)
df.plot(kind='line', x='time', y='close', ax=axs)
df.plot(kind='line', x='time', y='vol', ax=axs)
plt.figure(figsize = (18,9))
plt.plot(range(df.shape[0]),(df['low']+df['high'])/2.0)
plt.plot(range(df.shape[0]),(df['volume'])/1000000)
plt.xticks(range(0,df.shape[0],1500),df['time'].loc[::1500],rotation=15)
plt.show()

# %%
df.tail(10)
# Out:
#                        open    high     low   close    volume  \
# 2020-04-15 15:44:00  5.6750  5.6993  5.6750  5.6926   35089.0
# 2020-04-15 15:46:00  5.7000  5.7050  5.6900  5.7050  130161.0
# 2020-04-15 15:48:00  5.7050  5.7099  5.6800  5.6850   81579.0
# 2020-04-15 15:50:00  5.6893  5.7100  5.6893  5.7100   66375.0
# 2020-04-15 15:52:00  5.6950  5.7100  5.6900  5.7050  129438.0
# 2020-04-15 15:54:00  5.7097  5.7200  5.7030  5.7150   59632.0
# 2020-04-15 15:56:00  5.7150  5.7200  5.7100  5.7186  162228.0
# 2020-04-15 15:58:00  5.7200  5.7400  5.7200  5.7398   89971.0
# 2020-04-15 16:00:00     NaN     NaN     NaN     NaN       NaN
# 2020-04-15 16:01:04  5.7450  5.7450  5.7450  5.7450       0.0
#
#                                    time       vol
# 2020-04-15 15:44:00 2020-04-15 15:44:00  0.035089
# 2020-04-15 15:46:00 2020-04-15 15:46:00  0.130161
# 2020-04-15 15:48:00 2020-04-15 15:48:00  0.081579
# 2020-04-15 15:50:00 2020-04-15 15:50:00  0.066375
# 2020-04-15 15:52:00 2020-04-15 15:52:00  0.129438
# 2020-04-15 15:54:00 2020-04-15 15:54:00  0.059632
# 2020-04-15 15:56:00 2020-04-15 15:56:00  0.162228
# 2020-04-15 15:58:00 2020-04-15 15:58:00  0.089971
# 2020-04-15 16:00:00 2020-04-15 16:00:00       NaN
# 2020-04-15 16:01:04 2020-04-15 16:01:04  0.000000

# %%
df.describe()
# Out:
#               open         high          low        close        volume  \
# count  6246.000000  6246.000000  6246.000000  6246.000000  6.246000e+03
# mean      6.590240     6.612987     6.567712     6.589661  2.425303e+05
# std       2.328104     2.329035     2.327494     2.328286  3.252376e+05
# min       3.755000     3.777600     3.750000     3.755000  0.000000e+00
# 25%       5.020000     5.040000     5.000000     5.020000  9.726625e+04
# 50%       5.675000     5.690000     5.650000     5.671800  1.644805e+05
# 75%       7.220000     7.250000     7.200000     7.219400  2.809228e+05
# max      12.150000    12.250000    12.069400    12.150000  1.185530e+07
#
#                vol
# count  6246.000000
# mean      0.242530
# std       0.325238
# min       0.000000
# 25%       0.097266
# 50%       0.164480
# 75%       0.280923
# max      11.855305

# %%
df.isnull().sum()
# Out:
# open      71
# 2020-04-08 13:34:00 2020-04-08 13:34:00  0.494339
# 2020-04-08 13:36:00 2020-04-08 13:36:00  0.473877
# 2020-04-08 13:38:00 2020-04-08 13:38:00  0.141394
# ...                                 ...       ...
# 2020-04-09 19:50:00 2020-04-09 19:50:00  0.999726
# 2020-04-09 19:52:00 2020-04-09 19:52:00  0.439431
# 2020-04-09 19:54:00 2020-04-09 19:54:00  0.606054
# 2020-04-09 19:56:00 2020-04-09 19:56:00  1.061093
# 2020-04-09 19:58:00 2020-04-09 19:58:00  2.921401
#
# [390 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as dates
import matplotlib.ticker as ticker
import matplotlib
import pandas as pd
import datetime
import pytz

# tz=pytz.timezone('US/Eastern')

tf = pd.read_json('training.data.txt', orient='split')
# tf.fillna(df.mean(), inplace=True)
tf.drop_duplicates(inplace=True)
tf = round(tf, 2)

fig, ax = plt.subplots(figsize=(18,9))
et = round(tf.loc[tf['symbol']=='ET'],2)
et = et.sort_values(by='timestamp')
# et.drop(index=114, inplace=True)
et.drop(index=12, inplace=True)
et.drop(index=39, inplace=True)
et['ma'] = round(et["close"].rolling(window=10).mean(),2)
# et['mean'] = round((et["high"] + et["low"])/2 ,2)
# et['delta'] = round(et['close'].diff(1), 2)
et['trend'] = round(et['delta'].cumsum(), 2)
et['signal'] = round(et["delta"] - et["trend"],2)

df= et[:1800]
# df.index
df.index = df['timestamp']
df.index = df.index.tz_localize(tz='UTC')
df.index = df.index.tz_convert('US/Eastern')
plt.grid(True)
plt.xlabel('time')
plt.ylabel('price')
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
loc = ticker.MultipleLocator(0.02)
ax.yaxis.set_major_locator(loc)

ax.plot(df.index, df['close'], label='close', color='blue', marker='.')
ax.plot(df.index, df['ma'], label='mov. avg.', color='blue', marker='.')
ax.fill_between(df.index, df['low'], df['high'], label='l-h', alpha=.3, ec='red', fc='yellow')

# ax.fill_between(df.index, df['low'], df['high'], label='l-h', alpha=.3, ec='red', fc='yellow')
# ax.plot(df.index, df['close'], label='close', color='blue', marker='.')
## https://matplotlib.org/3.1.1/api/axis_api.html?highlight=axis#axis-label
## https://matplotlib.org/3.1.1/api/axes_api.html#matplotlib.axes.Axes
matplotlib.rcParams['timezone'] = 'US/Eastern'
# ax.xaxis_date(tz=('US/Eastern'))
# ax.xaxis.set_minor_locator(dates.SecondLocator(interval=20))   
# ax.xaxis.set_minor_formatter(dates.DateFormatter('%S'))
# ax.xaxis.set_major_locator(dates.HourLocator(interval=1))    # every day
ax.xaxis.set_major_locator(dates.MinuteLocator(interval=5))    # every day
ax.xaxis.set_major_formatter(dates.DateFormatter('\n%M\n%H'))
# ax.xaxis.set_major_formatter(dates.DateFormatter('\n%H:M:S\n%d %b %Y'))
ax.set_xlim([pd.to_datetime('2020-05-22 13:30:00')], [pd.to_datetime('2020-05-22 14:30:00', utc=False)])
# ax.set_xlim([pd.to_datetime('2020-04-21 13:30')], [pd.to_datetime('2020-04-21 20:05', utc=False)])
# ax.xaxis.set_minor_locator(dates.HourLocator(interval=4))   # every 4 hours
# ax.xaxis.set_minor_formatter(dates.DateFormatter('%H:%M'))  # hours and minutes
# ax.xaxis.set_major_locator(dates.DayLocator(interval=1))    # every day
# ax.xaxis.set_major_formatter(dates.DateFormatter('\n%d-%m-%Y')) 
plt.legend(loc='best')
plt.show()

# %%
import pytz
pd.DatetimeIndex(df.index, tz=(pytz.timezone('US/Eastern')))
# Out:
# DatetimeIndex(['2020-04-13 13:30:00-04:00', '2020-04-13 13:32:00-04:00',
#                '2020-04-13 13:34:00-04:00', '2020-04-13 13:36:00-04:00',
#                '2020-04-13 13:38:00-04:00', '2020-04-13 13:40:00-04:00',
#                '2020-04-13 13:42:00-04:00', '2020-04-13 13:44:00-04:00',
#                '2020-04-13 13:46:00-04:00', '2020-04-13 13:48:00-04:00',
#                ...
#                '2020-04-13 19:30:00-04:00', '2020-04-13 19:32:00-04:00',
#                '2020-04-13 19:34:00-04:00', '2020-04-13 19:36:00-04:00',
#                '2020-04-13 19:38:00-04:00', '2020-04-13 19:40:00-04:00',
#                '2020-04-13 19:42:00-04:00', '2020-04-13 19:44:00-04:00',
#                '2020-04-13 19:46:00-04:00', '2020-04-13 19:48:00-04:00'],
#               dtype='datetime64[ns, US/Eastern]', length=190, freq=None)

# %%
# df.fillna(df.mean())
et[0:60]
# df[100:]
# Out:
#      symbol  close   low  high   volume           timestamp easterntime  \
# 12       ET   8.09  7.63  8.12   271217 2020-05-04 20:00:01    16:00:01
# 39       ET   8.09  7.63  8.12   271218 2020-05-04 20:00:01    16:00:01
# 59       ET   8.39  8.38  8.40   761248 2020-05-05 13:30:12    09:30:12
# 128      ET   8.39  8.38  8.40   768003 2020-05-05 13:30:13    09:30:13
# 106      ET   8.39  8.38  8.40   794311 2020-05-05 13:30:16    09:30:16
# 169      ET   8.43  8.38  8.43   861441 2020-05-05 13:30:27    09:30:27
# 208      ET   8.44  8.38  8.44   880761 2020-05-05 13:30:38    09:30:38
# 258      ET   8.44  8.38  8.44   889528 2020-05-05 13:30:43    09:30:43
# 267      ET   8.42  8.38  8.44   948909 2020-05-05 13:30:48    09:30:48
# 295      ET   8.42  8.38  8.44   973409 2020-05-05 13:30:52    09:30:52
# 326      ET   8.42  8.38  8.44   989953 2020-05-05 13:30:54    09:30:54
# 365      ET   8.41  8.38  8.44  1014814 2020-05-05 13:31:02    09:31:02
# 382      ET   8.40  8.38  8.44  1035922 2020-05-05 13:31:08    09:31:08
# 419      ET   8.40  8.38  8.44  1048872 2020-05-05 13:31:13    09:31:13
# 441      ET   8.40  8.38  8.44  1072818 2020-05-05 13:31:18    09:31:18
# 473      ET   8.41  8.38  8.44  1075237 2020-05-05 13:31:22    09:31:22
# 500      ET   8.41  8.38  8.44  1080808 2020-05-05 13:31:27    09:31:27
# 1964     ET   8.51  8.38  8.52  1934151 2020-05-05 13:34:23    09:34:23
# 2023     ET   8.51  8.38  8.52  1951411 2020-05-05 13:34:25    09:34:25
# 2066     ET   8.51  8.38  8.52  1957404 2020-05-05 13:34:34    09:34:34
# 2115     ET   8.51  8.38  8.52  2020192 2020-05-05 13:34:38    09:34:38
# 2120     ET   8.49  8.38  8.52  2063352 2020-05-05 13:34:43    09:34:43
# 2179     ET   8.48  8.38  8.52  2073975 2020-05-05 13:34:47    09:34:47
# 2229     ET   8.49  8.38  8.52  2150257 2020-05-05 13:34:54    09:34:54
# 2292     ET   8.49  8.38  8.52  2180523 2020-05-05 13:34:57    09:34:57
# 2337     ET   8.47  8.38  8.52  2208355 2020-05-05 13:35:02    09:35:02
# 2383     ET   8.47  8.38  8.52  2213931 2020-05-05 13:35:09    09:35:09
#
#       delta  trend  signal
# 12      NaN    NaN     NaN
# 39     0.00   0.00    0.00
# 59     0.30   0.30    0.00
# 128    0.00   0.30   -0.30
# 106    0.00   0.30   -0.30
# 169    0.04   0.34   -0.30
# 208    0.01   0.35   -0.34
# 258    0.00   0.35   -0.35
# 267   -0.02   0.33   -0.35
# 295    0.00   0.33   -0.33
# 326    0.00   0.33   -0.33
# 365   -0.01   0.32   -0.33
# 382   -0.01   0.31   -0.32
# 419    0.00   0.31   -0.31
# 441    0.00   0.31   -0.31
# 473    0.01   0.32   -0.31
# 500    0.00   0.32   -0.32
# 528    0.00   0.32   -0.32
# 590    0.03   0.35   -0.32
# 617    0.03   0.38   -0.35
# 642   -0.01   0.37   -0.38
# 685    0.01   0.38   -0.37
# 708    0.00   0.38   -0.38
# 766   -0.01   0.37   -0.38
# 783    0.02   0.39   -0.37
# 856   -0.01   0.38   -0.39
# 900    0.00   0.38   -0.38
# 914   -0.02   0.36   -0.38
# 986    0.00   0.36   -0.36
# 1011   0.02   0.38   -0.36
# 1077  -0.02   0.36   -0.38
# 1088   0.03   0.39   -0.36
# 1139   0.00   0.39   -0.39
# 1184   0.00   0.39   -0.39
# 1233   0.00   0.39   -0.39
# 1298   0.00   0.39   -0.39
# 1343   0.00   0.39   -0.39
# 1355   0.01   0.40   -0.39
# 1412   0.03   0.43   -0.40
# 1449  -0.01   0.42   -0.43
# 1494   0.00   0.42   -0.42
# 1542   0.00   0.42   -0.42
# 1584  -0.01   0.41   -0.42
# 1662   0.01   0.42   -0.41
# 1671   0.00   0.42   -0.42
# 1729   0.00   0.42   -0.42
# 1763   0.01   0.43   -0.42
# 1837   0.00   0.43   -0.43
# 1882   0.00   0.43   -0.43
# 1917   0.00   0.43   -0.43
# 1964  -0.01   0.42   -0.43
# 2023   0.00   0.42   -0.42
# 2066   0.00   0.42   -0.42
# 2115   0.00   0.42   -0.42
# 2120  -0.02   0.40   -0.42
# 2179  -0.01   0.39   -0.40
# 2229   0.01   0.40   -0.39
# 2292   0.00   0.40   -0.40
# 2337  -0.02   0.38   -0.40
# 2383   0.00   0.38   -0.38

# %%
import datetime
import pytz
tz = pytz.timezone('US/Eastern')
usTime = datetime.datetime.now(tz)
int(usTime.timestamp())
# int((datetime.datetime(usTime.year, usTime.month, usTime.day, 9, 30, tzinfo=usTime.tzinfo) - datetime.datetime.now(tz)).total_seconds())
# usTime.timestamp()
# usTime.tzinfo
# Out:
# 1588258978

# %%
import pandas as pd
import json

file = 'my.txt'
with open(file) as train_file:
     d = json.load(train_file)
df = pd.DataFrame(d)

df[df['symbol']=='ET'].sort_values(by='timestamp')[-6:]
# Out:
#       symbol  close   low  high    volume   timestamp easterntime
# 22988     ET   7.38  7.28  7.49   5834147  1588083307    10:15:07
# 23021     ET   7.37  7.28  7.49   5881061  1588083313    10:15:13
# 23076     ET   7.36  7.28  7.49   5886218  1588083316    10:15:16
# 23106     ET   7.36  7.28  7.49   5886308  1588083316    10:15:16
# 23157     ET   7.36  7.28  7.49   5886308  1588083316    10:15:16
# 23186     ET   7.72  7.33  7.79  14780363  1588173767    11:22:47

# %%
df['symbol'][-1000:].unique()
# Out:
# array(['DB', 'NRZ', 'CZR', 'KGC', 'IVZ', 'NOK', 'AUY', 'HAL', 'PBR',
#        'GPS', 'RLLCF', 'VER', 'GE', 'AMRN', 'ET', 'SDC', 'BBD', 'SIRI',
#        'PBR-A', 'HBI', 'LYG', 'NIO', 'COTY', 'PE', 'NMHLY', 'NBL', 'FCX',
#        'CX', 'ABEV', 'KIM', 'ITUB', 'AM', 'HBAN', 'F', 'VALE', 'JBLU',
#        'ZNGA', 'CVE', 'MRO', 'PK', 'NLY', 'GGB', 'WPX'], dtype=object)

# %%
# float(a[2:3]["close"].values[0])
int(time.time())
# Out:
# 1588518816

# %%
df = pd.DataFrame({
...     'FR': [4.0405, 4.0, 4.3149],
...     'GR': [-1.00, 0.00, -1.89],
...     'IT': [804.74, 1.0, 860.13]})
# z = df['GR'] == 0
# m = df['GR'] < 0
# p = df['GR'] > 0
# str(df)
# df
# df.drop(df[-1:].index, inplace=True)
# df[:1]
# [df.iloc[0:3]['GR'].to_numpy()]
# [df['GR'].to_numpy(), '%']
df.iloc[-2]['GR']
# Out:
# 0.0

# %%
import datetime
import pytz
import time
tz = pytz.timezone('US/Eastern')
usTime = datetime.datetime.now(tz)
start= datetime.datetime(usTime.year, usTime.month, 18, 16, 30, tzinfo=usTime.tzinfo)
start.timestamp()
# int((datetime.datetime(usTime.year, usTime.month, usTime.day, 9, 30, tzinfo=usTime.tzinfo) - datetime.datetime(1970,1,1, tzinfo=usTime.tzinfo)).total_seconds()) 
# time.mktime(start.timetuple())
# usTime.day
# (datetime.datetime(usTime.year, usTime.month, usTime.day, 9, 30, tzinfo=usTime.tzinfo) - datetime.datetime(1970,1,1)).total_seconds()
# Out:
# 1589833800.0
